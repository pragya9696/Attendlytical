# %%
import sounddevice as sd
from scipy.io.wavfile import write
import wavio as wv
  
freq = 44100
duration = 60

recording = sd.rec(int(duration * freq), 
                   samplerate=freq, channels=2)
  

sd.wait()
wv.write("lecture/lecture.wav", recording, freq, sampwidth=2)

# %%
filename = "lecture/lecture.wav"
import speech_recognition as sr
r = sr.Recognizer()
with sr.AudioFile(filename) as source:
    # listen for the data (load audio to memory)
    audio_data = r.record(source)
    # recognize (convert from speech to text)
    text = r.recognize_google(audio_data)
    f = open("lecture/lecture.txt", "w")
    f.write(text)
    f.close()
# Out:
# ---------------------------------------------------------------------------
# UnknownValueError                         Traceback (most recent call last)
# Input In [2], in <cell line: 4>()
#       6 audio_data = r.record(source)
#       7 # recognize (convert from speech to text)
# ----> 8 text = r.recognize_google(audio_data)
#       9 f = open("lecture/lecture.txt", "w")
#      10 f.write(text)
#
# File ~\anaconda3\lib\site-packages\speech_recognition\__init__.py:858, in Recognizer.recognize_google(self, audio_data, key, language, show_all)
#     856 # return results
#     857 if show_all: return actual_result
# --> 858 if not isinstance(actual_result, dict) or len(actual_result.get("alternative", [])) == 0: raise UnknownValueError()
#     860 if "confidence" in actual_result["alternative"]:
#     861     # return alternative with highest confidence score
#     862     best_hypothesis = max(actual_result["alternative"], key=lambda alternative: alternative["confidence"])
#
# UnknownValueError:

# %%
from transformers import pipeline

# %%
summarizer=pipeline("summarization")

# %%
article=open("lecture/lecture.txt", "r").read()
c=summarizer(article,max_length=150,min_length=20,do_sample=False)
text=c[0]["summary_text"]
f = open("lecture/summary/summary.txt", "w")
f.write(text)
f.close()

# %%
from gtts import gTTS
  
# This module is imported so that we can 
# play the converted audio
import os
  
# The text that you want to convert to audio
with open('lecture/summary/summary.txt') as f:
    lines = f.readlines()
text=""
for x in lines:
    text=text+x
tts = gTTS(text)
tts.save("lecture/summary/summary.mp3")
